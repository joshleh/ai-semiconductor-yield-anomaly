# %%
# Imports
import pandas as pd
from src.ingestion.load_data import load_raw_data, basic_sanity_checks

# %%
# Load data
df = load_raw_data("manufacturing_data.csv")
basic_sanity_checks(df)

# %%
df.shape
df.head()

# %%
df.isnull().mean().sort_values(ascending=False).head(10)

# %%
# Target distribution (if label exists)
df["yield"].value_counts(normalize=True)
